# %%
import pandas as pd

train = pd.read_csv('/content/drive/MyDrive/데이터분석 기초강의/iris/iris_train.csv')

train.head()
# Out:
#    id     species  ...  sepal width (cm)  petal width (cm)
# 0   0      setosa  ...               2.9               0.2
# 1   1  versicolor  ...               3.2               1.5
# 2   2   virginica  ...               2.8               1.8
# 3   3   virginica  ...               3.6               2.5
# 4   4      setosa  ...               3.0               0.2
#
# [5 rows x 6 columns]

# %%
# 데이터 방정식 Y= aX+b

sepal_length = train['sepal length (cm)']
sepal_width = train['sepal width (cm)']

sepal_width
# Out:
# 0     2.9
# 1     3.2
# 2     2.8
# 3     3.6
# 4     3.0
#      ...
# 70    2.8
# 71    2.9
# 72    2.2
# 73    2.4
# 74    3.1
# Name: sepal width (cm), Length: 75, dtype: float64

# %%
import numpy as np

sepal_length_mean = np.mean(sepal_length)
sepal_width_mean = np.mean(sepal_width)

# a구하기
print(f"꽃받침 길이의 평균:{sepal_length_mean:2f} \n꽃받침 너비의 평균:{sepal_width_mean:2f}")
print(f"따라서 꽃받침 너비는 꽃받침 길이의 평균 {sepal_width_mean/sepal_length_mean:2f}배 입니다")
# Out:
# 꽃받침 길이의 평균:6.044000
# 꽃받침 너비의 평균:2.958667
# 따라서 꽃받침 너비는 꽃받침 길이의 평균 0.489521배 입니다

# %%
# b구하기
b = sepal_width_mean - 0.5 * sepal_length_mean

print(f"업데이트 된 방정식의 b는 {b:2f}입니다.")
# Out:
# 업데이트 된 방정식의 b는 -0.063333입니다.

# %%
predict_sepal_width = 0.5 * sepal_length - 0.06
predict_sepal_width
# Out:
# 0     2.14
# 1     3.14
# 2     3.04
# 3     3.54
# 4     2.39
#       ...
# 70    3.19
# 71    2.74
# 72    3.04
# 73    2.39
# 74    3.39
# Name: sepal length (cm), Length: 75, dtype: float64

# %%
# sepal_width 예측결과 평가

def MAE(true, pred):
  score = np.mean(np.abs(true-pred))
  return score

real_sepal_width = sepal_width.copy()

mean_error = MAE(real_sepal_width, predict_sepal_width)

print(f"이 방정식의 평균 에러는 {mean_error:2f}입니다.")
# Out:
# 이 방정식의 평균 에러는 0.432133입니다.

# %%
# petal_width 방정식 만들기

petal_length = train['petal length (cm)']
petal_width = train['petal width (cm)']

petal_length_mean = np.mean(petal_length)
petal_width_mean = np.mean(petal_width)

print(f"꽃잎 길이의 평균:{petal_length_mean:2f}\n꽃잎 너비의 평균{petal_width_mean:2f}")
print(f'따라서 꽃잎 너비는 꽃잎 길이의 평균{petal_width_mean/petal_length_mean:2f}배 입니다.')

a = petal_width_mean/petal_length_mean

b = petal_width_mean - 0.32 * petal_length_mean

print(f'업데이트 된 방정식의 b는 {b:2f}입니다.')
# Out:
# 꽃잎 길이의 평균:4.258667
# 꽃잎 너비의 평균1.384000
# 따라서 꽃잎 너비는 꽃잎 길이의 평균0.324984배 입니다.
# 업데이트 된 방정식의 b는 0.021227입니다.

# %%
predict_petal_width = 0.32 * petal_length - 0.02

real_petal_width = petal_width.copy()

mean_error = MAE(real_petal_width, predict_petal_width)

print(f'이 방정식의 평균 에러는 {mean_error:2f}입니다.')
# Out:
# 이 방정식의 평균 에러는 0.206453입니다.

# %%
# test_data 예측하기

test = pd.read_csv('/content/drive/MyDrive/데이터분석 기초강의/iris/iris_test.csv')

test.head()
# Out:
#    id    species  sepal length (cm)  petal length (cm)
# 0   0     setosa                5.4                1.7
# 1   1     setosa                5.7                1.5
# 2   2     setosa                5.3                1.5
# 3   3     setosa                5.1                1.9
# 4   4  virginica                6.0                4.8

# %%
sepal_length = train['sepal length (cm)']
petal_length = train['petal length (cm)']

predict_sepal_width = 0.5 * sepal_length - 0.06
predict_petal_width = 0.3 * petal_length - 0.75

predict_petal_width
# Out:
# 0    -0.33
# 1     0.60
# 2     0.69
# 3     1.08
# 4    -0.33
#       ...
# 70    0.63
# 71    0.33
# 72    0.60
# 73    0.24
# 74    0.72
# Name: petal length (cm), Length: 75, dtype: float64

# %%
#제출

submission = pd.read_csv('/content/drive/MyDrive/데이터분석 기초강의/iris/sample_submission.csv')
submission.head()
# Out:
#    id  sepal width (cm)  petal width (cm)
# 0   0                 0                 0
# 1   1                 0                 0
# 2   2                 0                 0
# 3   3                 0                 0
# 4   4                 0                 0

# %%
submission['sepal width (cm)'] = predict_sepal_width
submission['petal width (cm)'] = predict_petal_width

submission
# Out:
#     id  sepal width (cm)  petal width (cm)  petal_width (cm)
# 0    0              2.14             -0.33             -0.33
# 1    1              3.14              0.60              0.60
# 2    2              3.04              0.69              0.69
# 3    3              3.54              1.08              1.08
# 4    4              2.39             -0.33             -0.33
# ..  ..               ...               ...               ...
# 70  70              3.19              0.63              0.63
# 71  71              2.74              0.33              0.33
# 72  72              3.04              0.60              0.60
# 73  73              2.39              0.24              0.24
# 74  74              3.39              0.72              0.72
#
# [75 rows x 4 columns]

# %%
submission.drop('petal_width (cm)', axis=1, inplace=True)
submission
# Out:
#     id  sepal width (cm)  petal width (cm)
# 0    0              2.14             -0.33
# 1    1              3.14              0.60
# 2    2              3.04              0.69
# 3    3              3.54              1.08
# 4    4              2.39             -0.33
# ..  ..               ...               ...
# 70  70              3.19              0.63
# 71  71              2.74              0.33
# 72  72              3.04              0.60
# 73  73              2.39              0.24
# 74  74              3.39              0.72
#
# [75 rows x 3 columns]

# %%
submission.to_csv('submission.csv',index=False)
